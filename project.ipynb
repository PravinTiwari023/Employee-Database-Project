# %% [markdown]
# Library Part
# -----------------

# %%
import os
import sqlite3
import pandas as pd
from subprocess import call #this is use to clear screen
from time import sleep

# %% [markdown]
# Class Part
# ---------------

# %%
def clear():
	# check and make call for specific operating system
	_ = call('clear' if os.name =='posix' else 'cls')

class Employee:
    """A simple employee class"""

    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay

    @property
    def email(self):
        return '{}.{}@email.com'.format(self.first, self.last)

    @property
    def fullname(self):
        return '{} {}'.format(self.first, self.last)

    def _repr_(self):
        return "Employee('{}','{}','{}')".format(self.first, self.last, self.pay)

# %% [markdown]
# Function and SQLite queries
# -----------------------------------------

# %%
conn = sqlite3.connect('employee.db')

c = conn.cursor()


def insert_emp(emp):
    with conn:
        c.execute("INSERT INTO employees VALUES (:first,:last,:pay)",
                  {'first': emp.first, 'last': emp.last, 'pay': emp.pay})

def get_emp_by_firstname(firstname):
    c.execute("select * from employees where first=:first", {'first': firstname})
    return c.fetchall()

def show_all():
    data = pd.read_sql_query("select * from employees",conn)
    return data


def get_emp_by_lastname(lastname):
    c.execute("select * from employees where last=:last", {'last': lastname})
    return c.fetchall()


def update_pay(first , last , pay):
    with conn:
        c.execute("""update employees set pay=:pay
					where first= :first and last= :last""",
                  {'pay': pay, 'first': first, 'last': last})


def remove_emp(first, last):
    with conn:
        c.execute("delete from employees where first= :first and last= :last",
                  {'first': first, 'last': last})

# %% [markdown]
# _____________
# CODE SECTION
# -----------------------

# %%
while True :
    try:
        list = []

        a = int(input("1. First Time Using\n2. Already User\nYour Answer :"))
        print()

        if a == 1:
            c.execute("""CREATE TABLE employees (
        			    first text,
        			    last text,
        			    pay integer
        			    )""")

            n = int(input("Enter The Number Of Users :"))
            i = 1
            while i <= n:
                print()
                print("Enter The Details Of Employee ", i)
                print()
                First = input("Enter The First Name :")
                Last = input("Enter The Last Name :")
                Pay = int(input("Enter The Payment :"))
                object = Employee(First, Last, Pay)
                list.append(object)
                print()
                i += 1

            for i in list:
                insert_emp(i)
                print("Employee :" + str(i) + " Added")
            print()
            sleep(1)

            print("1. Search Employee By There First Name.")
            print("2. Search Employee By There Last Name.")
            print("3. Add Employee Into The Database.")
            print("4. Update The Payment Of Employee.")
            print("5. Delete The Employee Information.")
            print("6. Show all Employee.")
            print("7. Exit.")
            print()

            choice = int(input("You Answer :"))
            print()

            while choice > 0:

                if choice == 1:
                    info = input(
                        "Enter First Name Which Suppose To Be Search\n(Please Enter Valid First Name)\nFirst Name :")
                    ans = get_emp_by_firstname(info)
                    sleep(1)
                    print()
                    print("User Information's Are In The Form Of List")
                    print("Information :")
                    print()
                    for i in range(len(ans)):
                        print('First Name :',ans[i][0])
                        print('Last Name :',ans[i][1])
                        print('Payment :',ans[i][2])
                        print()
                    print()

                elif choice == 2:
                    info = input(
                        "Enter Last Name Which Suppose To Be Search\n(Please Enter Valid Last Name)\nLast Name :")
                    ans = get_emp_by_lastname(info)
                    sleep(1)
                    clear()
                    print()
                    print("User Information's Are In The Form Of List")
                    print("Information :")
                    print()
                    for i in range(len(ans)):
                        print('First Name :',ans[i][0])
                        print('Last Name :',ans[i][1])
                        print('Payment :',ans[i][2])
                        print()
                    print()

                elif choice == 3:
                    print("Enter Details Of Employee")
                    print()
                    newfirst = input("Enter First Name :")
                    newlast = input("Enter Last Name :")
                    newpay = int(input("Enter Payment :"))
                    newobject = Employee(newfirst, newlast, newpay)
                    insert_emp(newobject)
                    print()

                elif choice == 4:
                    empfirst = input("Enter Employee Information Which You Want To Update\nEmployee First Name :")
                    emplast = input("Enter Last Name :")
                    print("NOTE : You Can Only Update During Runtime Else It'll Show Error\n")
                    newpay = int(input("Enter Update Payment\nEnter Update :"))
                    update_pay(empfirst, emplast, newpay)
                    print()

                elif choice == 5:
                    empfirst = input("Enter Employee Information Which You Want To Delete\nEnter Employee First Name :")
                    emplast = input("Enter Employee Last Name :")
                    print()
                    otp = int(input("Type The Number Written Here : 6245\nEnter OTP :"))
                    print()
                    if otp == 6245:
                        remove_emp(empfirst, emplast)
                        sleep(1)
                        clear()
                        print("Employee Information Deleted.")
                    else:
                        print("Sorry Invalid OTP Going Back To Main Menu.")
                    print()

                elif choice == 6:
                    sleep(1)
                    clear()
                    ans = show_all()
                    print(ans)
                    print('\n')

                elif choice == 7:
                    print("Thank You")
                    os._exit(os.EX_OK)

                else:
                    print("You Have Selected Invalid Input")
                    print()

                print("1. Search Employee By There First Name.")
                print("2. Search Employee By There Last Name.")
                print("3. Add Employee Into The Database.")
                print("4. Update The Payment Of Employee.")
                print("5. Delete The Employee Information.")
                print("6. Show All Employees Data")
                print("7. Exit.")
                print()

                choice = int(input("Your Answer :"))
                print()

        elif a == 2:

            n = int(input("Enter The Number Of Employees :"))
            i = 1
            while i <= n:
                print()
                print("Enter The Details Of Employee ", i)
                print()
                First = input("Enter The First Name :")
                Last = input("Enter The Last Name :")
                Pay = int(input("Enter The Payment :"))
                object = Employee(First, Last, Pay)
                list.append(object)
                print()
                i += 1

            for i in list:
                insert_emp(i)
                print("Employee :" + str(i) + " Added")
            print()
            sleep(1)

            print("1. Search Employee By There First Name.")
            print("2. Search Employee By There Last Name.")
            print("3. Add Employee Into The Database.")
            print("4. Update The Payment Of Employee.")
            print("5. Delete The Employee Information.")
            print("6. Show All Employees Data")
            print("7. Exit.")
            print()

            choice = int(input("Your Answer :"))
            print()

            while choice > 0:

                if choice == 1:
                    info = input(
                        "Enter First Name Which Suppose To Be Search\n(Please Enter Valid First Name)\nFirst Name :")
                    ans = get_emp_by_firstname(info)
                    sleep(1)
                    clear()
                    print()
                    print("User Information's Are In The Form Of List")
                    print("Information :")
                    print()
                    for i in range(len(ans)):
                        print('First Name :',ans[i][0])
                        print('Last Name :',ans[i][1])
                        print('Payment :',ans[i][2])
                        print()
                    print()

                elif choice == 2:
                    info = input(
                        "Enter Last Name Which Suppose To Be Search\n(Please Enter Valid Last Name)\nLast Name :")
                    ans = get_emp_by_lastname(info)
                    sleep(1)
                    clear()
                    print()
                    print("User Information's Are In The Form Of List")
                    print("Information :")
                    print()
                    for i in range(len(ans)):
                        print('First Name :',ans[i][0])
                        print('Last Name :',ans[i][1])
                        print('Payment :',ans[i][2])
                        print()
                    print()

                elif choice == 3:
                    print("Enter Details Of Employee")
                    print()
                    newfirst = input("Enter First Name :")
                    newlast = input("Enter Last Name :")
                    newpay = int(input("Enter Payment :"))
                    newobject = Employee(newfirst, newlast, newpay)
                    insert_emp(newobject)
                    print()

                elif choice == 4:
                    empfirst = input("Enter Employee Information Which You Want To Update\nEmployee First Name :")
                    emplast = input("Enter Last Name :")
                    print("NOTE : You Can Only Update During Runtime Else It'll Show Error\n")
                    newpay = int(input("Enter Update Payment\nEnter Update :"))
                    update_pay(empfirst, emplast, newpay)
                    print()

                elif choice == 5:
                    empfirst = input("Enter Employee Information Which You Want To Delete\nEnter Employee First Name :")
                    emplast = input("Enter Employee Last Name :")
                    print()
                    otp = int(input("Type The Number Written Here : 6245\nEnter OTP :"))
                    print()
                    if otp == 6245:
                        remove_emp(empfirst, emplast)
                        sleep(1)
                        clear()
                        print("Employee Information Deleted.")
                    else:
                        print("Sorry Invalid OTP Going Back To Main Menu.")
                    print()


                elif choice == 6:
                    sleep(1)
                    ans = show_all()
                    print(ans)
                    print('\n')

                elif choice == 7:
                    print("Thank You")
                    os._exit(os.EX_OK)

                else:
                    print("You Have Selected Invalid Input")
                    print()

                print("1. Search Employee By There First Name.")
                print("2. Search Employee By There Last Name.")
                print("3. Add Employee Into The Database.")
                print("4. Update The Payment Of Employee.")
                print("5. Delete The Employee Information.")
                print("6. Show All Employees Data")
                print("7. Exit.")
                print()

                choice = int(input("Your Answer :"))
                print()

        else :
            print("Please Enter (1 and 2) Accordingly")
            10/0

    except ValueError:
        print("\nCheck Your Input And Enter It Properly\n")

    except sqlite3.OperationalError:
        print("\nYour Are Already An User (PLEASE ENTER 2)\n")

    except ZeroDivisionError :
        print()
# Out:
# 1. First Time Using
# 2. Already User
# Your Answer :2
#
# Enter The Number Of Employees :0
#
# 1. Search Employee By There First Name.
# 2. Search Employee By There Last Name.
# 3. Add Employee Into The Database.
# 4. Update The Payment Of Employee.
# 5. Delete The Employee Information.
# 6. Show All Employees Data
# 7. Exit.
#
# Your Answer :6
#
#       first    last   pay
# 0    Pravin  Tiwari  1500
# 1   Vandana  Tiwari  1600
# 2      Alok   Singh  1500
# 3    Aditya   Dubey  1300
# 4     Rahul  Thakur  1700
# 5     Sneha  Tiwari  1400
# 6      Neha   Singh  1500
# 7     Aryan   Singh   900
# 8      Arya   Singh  1000
# 9    Shivam   Dubey   699
# 10   Shivam  Pandey  1000
# 11    user1      01  3400
# 12    user2      02  4535
# 13     user      22  4400
# 14     user      23  4300
# 15     user      24  4500
#
#
# 1. Search Employee By There First Name.
# 2. Search Employee By There Last Name.
# 3. Add Employee Into The Database.
# 4. Update The Payment Of Employee.
# ...

# %% [markdown]
# ######
